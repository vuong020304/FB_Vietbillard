# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../Data/officialfoden.csv')

# %%
# Chọn các hàng từ hàng 8 đến hàng 117
data_selected = data.iloc[8:125]

# Ghi lại DataFrame đã chọn vào file CSV
data_selected.to_csv('../Data/officialfoden_100.csv', index=False)

# %%
df = pd.read_csv('../Data/officialfoden_100.csv')

# %%
df
# Out:
#              post_id                                               text  \
# 0    889347669219012  CITY CITY CITY 🔵 Thanks my mate, @erling.haala...
# 1    885191366301309       No place like home 🏡\n\nKhông đâu bằng nhà 🏡
# 2    883053229848456  Our #EURO2024 place secured 🔒 Proud of this te...
# 3    875769617243484        Enjoyed that one! 😁\n\nRất thích điều đó! 😁
# 4    870104804476632  Another W 😎 Nice to get a goal too 🙏🏻\n\nMột W...
# ..               ...                                                ...
# 112  498546568299126  3️⃣ Points 1️⃣ Goal on the road. Let’s be havi...
# 113  470915591062224  Goal and three points… no better way to end th...
# 114  469016147918835  A Christmas cracker!! Enjoy City fans 🎄🎉\n\nMộ...
# 115  467163998104050                                               ❄️❄️
# 116  461965888623861  There are legends and then there are legends. ...
#
#                                              post_text  shared_text  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   post_id                        117 non-null    int64
#  1   text                           116 non-null    object
#  2   post_text                      116 non-null    object
#  3   shared_text                    0 non-null      float64
#  4   original_text                  71 non-null     object
#  5   time                           117 non-null    object
#  6   timestamp                      117 non-null    float64
#  7   image                          115 non-null    object
#  8   image_lowquality               117 non-null    object
#  9   images                         117 non-null    object
#  10  images_description             117 non-null    object
#  11  images_lowquality              117 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# post_id                            0
# text                               1
# post_text                          1
# shared_text                      117
# original_text                     46
# time                               0
# timestamp                          0
# image                              2
# image_lowquality                   0
# images                             0
# images_description                 0
# images_lowquality                  0
# images_lowquality_description      0
# video                            115
# video_duration_seconds           117
# video_height                     117
# video_id                         115
# video_quality                    117
# video_size_MB                    117
# video_thumbnail                  115
# video_watches                    117
# video_width                      117
# likes                            117
# comments                           0
# shares                             0
# ...

# %%
post_df = pd.DataFrame(df)
post_df.columns
# Out:
# Index(['post_id', 'text', 'post_text', 'shared_text', 'original_text', 'time',
#        'timestamp', 'image', 'image_lowquality', 'images',
#        'images_description', 'images_lowquality',
#        'images_lowquality_description', 'video', 'video_duration_seconds',
#        'video_height', 'video_id', 'video_quality', 'video_size_MB',
#        'video_thumbnail', 'video_watches', 'video_width', 'likes', 'comments',
#        'shares', 'post_url', 'link', 'links', 'user_id', 'username',
#        'user_url', 'is_live', 'factcheck', 'shared_post_id', 'shared_time',
#        'shared_user_id', 'shared_username', 'shared_post_url', 'available',
#        'comments_full', 'reactors', 'w3_fb_url', 'reactions', 'reaction_count',
#        'with', 'page_id', 'sharers', 'image_id', 'image_ids', 'video_ids',
#        'videos', 'was_live', 'fetched_time'],
#       dtype='object')

# %%
columns_to_keep = ['post_id', 'text', 'post_text', 'time', 'timestamp',
                   'comments', 'shares', 'comments_full', 'reactors', 'reactions',
                   'reaction_count']

# Giữ lại các cột cần thiết và loại bỏ các cột khác từ DataFrame
post_df = post_df[columns_to_keep]

# %%
post_df.columns
# Out:
# Index(['post_id', 'text', 'post_text', 'time', 'timestamp', 'comments',
#        'shares', 'comments_full', 'reactors', 'reactions', 'reaction_count'],
#       dtype='object')

# %%
post_df.isnull().sum()
# Out:
# post_id           0
# text              1
# post_text         1
# time              0
# timestamp         0
# comments          0
# shares            0
# comments_full     0
# reactors          0
# reactions         0
# reaction_count    0
# dtype: int64

# %%
# Có một số hàng khi lấy dữ liệu về bị thiếu nên ta cần loại bỏ các hàng đó
post_df = post_df.dropna()
post_df.isnull().sum()
# Out:
# post_id           0
# text              0
# post_text         0
# time              0
# timestamp         0
# comments          0
# shares            0
# comments_full     0
# reactors          0
# reactions         0
# reaction_count    0
# dtype: int64

# %%
post_df.shape
# Out:
# (116, 11)

# %%
# Chuyển dữ liệu sang file để nhìn cho trực quan hơn
path = '../Data/data_clean.csv'
post_df.to_csv(path, index=False)
